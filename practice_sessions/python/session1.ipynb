# %%
import pandas as pd 
import seaborn as sns

# %%
df = pd.read_csv("https://datahub.io/core/gdp-us/r/quarter.csv")

# %%
df.head()
# Out:
#          date  level-current  level-chained  change-current  change-chained
# 0  1947-04-01          246.3         1932.3             6.4            -0.4
# 1  1947-07-01          250.1         1930.3            17.3             6.4
# 2  1947-10-01          260.3         1960.7             9.3             6.0
# 3  1948-01-01          266.2         1989.5            10.5             6.7
# 4  1948-04-01          272.9         2021.9            10.0             2.3

# %%
df.describe()
# Out:
#        level-current  level-chained  change-current  change-chained
# count     281.000000     281.000000      281.000000      281.000000
# mean     5702.245552    7957.566904        6.521352        3.230605
# std      5753.256673    4625.897706        4.720991        3.888682
# min       246.300000    1930.300000       -7.700000      -10.000000
# 25%       698.400000    3780.200000        4.100000        1.200000
# 50%      3331.300000    6585.100000        6.000000        3.100000
# 75%      9926.100000   12323.300000        8.800000        5.300000
# max     19250.000000   17031.100000       26.800000       16.900000

# %%
sns.barplot(data=df)
# Out:
# <Axes: >

# %%
sns.histplot(data=df)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.pairplot(data=df)

# %%
num1 = 23
num2 = 44
num2 = 2+3j
num1 = num2.imag
print(num1,num2)
num2-num1
# Out:
# 3.0 (2+3j)
# (-1+3j)

# %%
name = 'pwskills'
name[0] = 'P'
_mu = 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 name = 'pwskills'
# ----> 2 name[0] = 'P'
#
# TypeError: 'str' object does not support item assignment

# %%
'pwskills'.upper().lower().isalnum()
# Out:
# True

# %%
for course in ['Data Science Masters', 'ML', 'data science masters', 'DL']:

    if len(course)!= 2:

        print('PwSkills' , end=' ')
# Out:
# PwSkills PwSkills

# %%
sum = 0

for i in range(1,100):

    sum += i

    if sum > 100:

        break

print(sum)
# Out:
# 105

# %%
num = 2
sum = 0

while num<= 20:
    sum+= num
    num+=2
    print(sum)
# Out:
# 2
# 6
# 12
# 20
# 30
# 42
# 56
# 72
# 90
# 110

# %%
a, b = [1,2,3], [4,5,6]
a[0] = 33
a+b
# Out:
# [33, 2, 3, 4, 5, 6]

# %%
t = (1,2,3)
t[0] = 444
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 t = (1,2,3)
# ----> 2 t[0] = 444
#
# TypeError: 'tuple' object does not support item assignment

# %%
t = (1,1,2,2,3)

# %%
t.i
# Out:
# (1, 1, 2, 2, 3)

# %%
s = {1,2,3}
s.ind

# %%
True or False and True
# Out:
# True

# %%
False or False and not(True)
# Out:
# False

# %%
"pwskills"[::-1].upper().replace("SLLIKSWP","pwskills").islower()
# Out:
# True

# %%
s = "I want to become data scientist"
for i in s.split():
    i.capitalize()
    print(i.title())
# Out:
# I
# Want
# To
# Become
# Data
# Scientist

# %%
tup = ("str")
type(tup)
# Out:
# str

# %%
tup = (100,)
print(tup*2)
# Out:
# (100, 100)

# %%
dt = {"A": 1, "B": "2"}
dt.get("age")

# %%
set1 = {1,2,3,4}
#set2 = (3,4,5)
set2 = set1.update(set1)
print(set2)
# Out:
# None

# %%
set1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 set1[0]
#
# TypeError: 'set' object is not subscriptable
