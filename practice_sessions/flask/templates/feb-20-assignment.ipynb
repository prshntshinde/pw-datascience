# %% [markdown]
# ### Q1. Explain GET and POST methods.

# %% [markdown]
# ---
# GET
# - Get method is mainly used at the client side to send a request to a specified server to get certain data or resources.
# - Using this method the server should only let us receive the data and not change its state.
#
# ---
#
# POST
# - Post method is mainly used at the client side to send data to a specified server in order to create or rewrite a particular resource/data.
# - This data sent to the server is stored in the request body of the HTTP request.
# - Post method eventually leads to the creation of a new resource or updating an existing one.

# %% [markdown]
# ### Q2. Why is request used in Flask?

# %% [markdown]
# - Request is an object that contains all the data sent from the Client to Server.
# - This data can be recovered using the GET/POST Methods.

# %% [markdown]
# ### Q3. Why is redirect() used in Flask?

# %% [markdown]
# - redirect() method is used in the Flask to send the user to a particular URL with the status code.
# - The same method is used for redirecting to other routes on the same application and external websites.

# %% [markdown]
# ### Q4. What are templates in Flask? Why is the render_template() function used?

# %% [markdown]
# - Templates are files that contain static data as well as placeholders for dynamic data.
# - A template is rendered with specific data to produce a final document.
# - Flask uses the Jinja template library to render templates.
# ---
# - render_template() method renders a template by name with the given context.
# - It will render the template files that are stored in the templates directory

# %% [markdown]
# ### Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %% [markdown]
# ![image.png](attachment:image.png)
