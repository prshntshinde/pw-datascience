# %% [markdown]
# ### Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# - Flask is a micro web framework which is written in python programming language.
# ---
# - Advantages
#     - Flask is a lightweight framework with minimalist features.
#     - Flask is compatible with the latest technologies such as machine learning, agile development, cloud technologies, etc.
#     - Flask provides an in-built debugger that offers virtual debugging.
#     - Flask offers in-built security features for common threats like CSRF, SQL Injection XSS, etc.

# %% [markdown]
# ### Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# App Routing
# - App Routing means mapping the URLs to a specific function that will handle the logic for that URL.
# - Modern web frameworks use more meaningful URLs to help users remember the URLs and make navigation simpler.

# %% [markdown]
# ### Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
# - Company Name: ABC Corporation
# - Location: India Contact
# - Detail: 999-999-9999
#
# Attach the screenshot of the output in Jupyter Notebook.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.

# %% [markdown]
# - To build a URL to a specific function, we can use the url_for() function.
# - It accepts the name of the function as its first argument and any number of keyword arguments, each corresponding to a variable part of the URL rule.

# %%
from flask import Flask
from flask import redirect
from flask import url_for

app = Flask(__name__)

# URL Building

@app.route("/admin")
def admin():
    return "<b>Hello Admin</b>. You have access to everything!!!"

@app.route("/guest/<guest>")
def guest(guest):
    return f"<b>Hello {guest}</b>. You are a guest and have limited access."


@app.route("/user/<name>")
def user(name):
    if name == 'admin':
        return redirect(url_for("admin"))
    else:
        return redirect(url_for('guest', guest=name))


if __name__ == "__main__":
    app.run(host="127.0.0.1", port=5000)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
